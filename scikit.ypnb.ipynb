# %%
import pandas as pd
import numpy as np
clima = pd.read_csv('datos.csv', names=['hora','temperatura','humedad'])
clima
# Out:
#                            hora  temperatura  humedad
# 0    "2022-02-06T16:37:15.711Z"         23.0     35.0
# 1    "2022-02-06T16:41:05.533Z"         23.0     35.0
# 2    "2022-02-06T16:47:08.500Z"         23.0     35.0
# 3    "2022-02-06T16:50:08.318Z"         23.0     35.0
# 4    "2022-02-06T16:53:07.340Z"         23.0     35.0
# ..                          ...          ...      ...
# 754  "2022-02-09T21:23:37.907Z"         21.0     36.0
# 755  "2022-02-09T21:33:37.910Z"         21.0     36.0
# 756  "2022-02-09T21:43:38.912Z"         21.0     37.0
# 757  "2022-02-09T21:53:38.415Z"         21.0     37.0
# 758  "2022-02-09T21:56:52.197Z"         21.0     37.0
#
# [759 rows x 3 columns]

# %%
y = clima.humedad
x = clima.temperatura
from sklearn.tree import DecisionTreeRegressor as dct
modelo = dct(random_state=1)
modelo.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_9748/3633272324.py in <module>
#       3 from sklearn.tree import DecisionTreeRegressor as dct
#       4 modelo = dct(random_state=1)
# ----> 5 modelo.fit(x, y)
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1250         """
#    1251
# -> 1252         super().fit(
#    1253             X, y,
#    1254             sample_weight=sample_weight,
#
# ~/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     156             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 157             X, y = self._validate_data(X, y,
# ...
